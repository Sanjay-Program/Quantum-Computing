# %%
# !pip install qubit
# Out:
# ^C
# Collecting qubit
#   Downloading qubit-0.0.1.tar.gz (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting Flask==0.11.1 (from qubit)
#   Downloading Flask-0.11.1-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting py-postgresql==1.1.0 (from qubit)
#   Downloading py-postgresql-1.1.0.zip (254 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pytest==3.0.3 (from qubit)
#   Downloading pytest-3.0.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting Jinja2>=2.4 (from Flask==0.11.1->qubit)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting Werkzeug>=0.7 (from Flask==0.11.1->qubit)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting click>=2.0 (from Flask==0.11.1->qubit)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting itsdangerous>=0.21 (from Flask==0.11.1->qubit)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting py>=1.4.29 (from pytest==3.0.3->qubit)
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: colorama in c:\users\sanja\desktop\quantumcomputing\quantum\lib\site-packages (from pytest==3.0.3->qubit) (0.4.6)
# Collecting MarkupSafe>=2.0 (from Jinja2>=2.4->Flask==0.11.1->qubit)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Downloading Flask-0.11.1-py2.py3-none-any.whl (80 kB)
# Downloading pytest-3.0.3-py2.py3-none-any.whl (169 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Building wheels for collected packages: qubit, py-postgresql
#   Building wheel for qubit (pyproject.toml): started
#   Building wheel for qubit (pyproject.toml): finished with status 'done'
#   Created wheel for qubit: filename=qubit-0.0.1-py3-none-any.whl size=15998 sha256=dda6741fcc08fa91175e21f706bc6ec098ff3b690f87766550937fe885c02b4a
#   Stored in directory: c:\users\sanja\appdata\local\pip\cache\wheels\e6\03\9a\a8ec7e9e8a46238268be07ab066afb361f40cf36323c8d9fbb
#   Building wheel for py-postgresql (pyproject.toml): started
#   Building wheel for py-postgresql (pyproject.toml): finished with status 'done'
#   Created wheel for py-postgresql: filename=py_postgresql-1.1.0-cp312-cp312-win_amd64.whl size=252686 sha256=e6f0b4e1acdcbb76a8a558c3e08c4f151dad09f2eef4a25f478d0e7da7dae637
#   Stored in directory: c:\users\sanja\appdata\local\pip\cache\wheels\28\6b\5a\328ded7d5d6783b5a51415bada6eee46450ea0767ccf398198
# Successfully built qubit py-postgresql
# Installing collected packages: py-postgresql, py, MarkupSafe, itsdangerous, click, Werkzeug, pytest, Jinja2, Flask, qubit
#
#    ----------------------------------------  0/10 [py-postgresql]
#    ----------------------------------------  0/10 [py-postgresql]
#    ----------------------------------------  0/10 [py-postgresql]
#    ----------------------------------------  0/10 [py-postgresql]
#    ----------------------------------------  0/10 [py-postgresql]
#    ----------------------------------------  0/10 [py-postgresql]
#    ----------------------------------------  0/10 [py-postgresql]
#    ---- -----------------------------------  1/10 [py]
#    ---- -----------------------------------  1/10 [py]
#    ---- -----------------------------------  1/10 [py]
#    ---- -----------------------------------  1/10 [py]
#    ---- -----------------------------------  1/10 [py]
#    ------------ ---------------------------  3/10 [itsdangerous]
#    ---------------- -----------------------  4/10 [click]
#    ---------------- -----------------------  4/10 [click]
#    ---------------- -----------------------  4/10 [click]
#    ---------------- -----------------------  4/10 [click]
#    -------------------- -------------------  5/10 [Werkzeug]
#    -------------------- -------------------  5/10 [Werkzeug]
#    -------------------- -------------------  5/10 [Werkzeug]
#    -------------------- -------------------  5/10 [Werkzeug]
#    -------------------- -------------------  5/10 [Werkzeug]
#    -------------------- -------------------  5/10 [Werkzeug]
#    -------------------- -------------------  5/10 [Werkzeug]
#    -------------------- -------------------  5/10 [Werkzeug]
#    -------------------- -------------------  5/10 [Werkzeug]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ---------------------------- -----------  7/10 [Jinja2]
#    ---------------------------- -----------  7/10 [Jinja2]
#    ---------------------------- -----------  7/10 [Jinja2]
#    ---------------------------- -----------  7/10 [Jinja2]
#    ---------------------------- -----------  7/10 [Jinja2]
#    -------------------------------- -------  8/10 [Flask]
#    -------------------------------- -------  8/10 [Flask]
#    -------------------------------- -------  8/10 [Flask]
#    -------------------------------- -------  8/10 [Flask]
#    ------------------------------------ ---  9/10 [qubit]
#    ------------------------------------ ---  9/10 [qubit]
#    ------------------------------------ ---  9/10 [qubit]
#    ---------------------------------------- 10/10 [qubit]
#
# Successfully installed Flask-0.11.1 Jinja2-3.1.6 MarkupSafe-3.0.2 Werkzeug-3.1.3 click-8.2.1 itsdangerous-2.2.0 py-1.11.0 py-postgresql-1.1.0 pytest-3.0.3 qubit-0.0.1

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
qc=QuantumCircuit(1,1)

qc.h(0)  # Apply Hadamard gate to qubit 0
qc.measure(0, 0)  # Measure qubit 0 into classical bit 0

simulator = Aer.get_backend('qasm_simulator')
job=simulator.run(qc,shorts=1000)
result=job.result()
counts=result.get_counts(qc)
print(counts)

labels=list(counts.keys()) #[0,1]
values=list(counts.values()) #[490,510]

colors=['blue','red']

plt.bar(labels, values, color=colors)
plt.xlabel('Measurement Result')
plt.ylabel('Counts')
plt.title('Measurement Results of Qubit 0')
plt.show(0)
# Out:
# {'0': 482, '1': 542}
